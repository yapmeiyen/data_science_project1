# %%
# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Fetching package metadata .............
# Solving package specifications: .
#
# Package plan for installation in environment /opt/conda/envs/DSX-Python35:
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib: 1.49-py_0   conda-forge
#     geopy:         1.17.0-py_0 conda-forge
#
# geographiclib- 100% |################################| Time: 0:00:00  24.30 MB/s
# geopy-1.17.0-p 100% |################################| Time: 0:00:00  34.56 MB/s
# Fetching package metadata .............
# Solving package specifications: .
#
# Package plan for installation in environment /opt/conda/envs/DSX-Python35:
#
# The following NEW packages will be INSTALLED:
#
#     altair:  2.2.2-py35_1 conda-forge
#     branca:  0.3.1-py_0   conda-forge
#     folium:  0.5.0-py_0   conda-forge
#     vincent: 0.4.4-py_1   conda-forge
#
# altair-2.2.2-p 100% |################################| Time: 0:00:00  55.37 MB/s
# ...

# %%
CLIENT_ID = 'RTZWY2Y3T1EVLYSCHAIHW4N5W5SGR21LOG1DJFIKWPQBXSZI' # your Foursquare ID
CLIENT_SECRET = 'A0CY0JWXE3MZV3IQX4AHQH1MICJI3X4D4UFSZC21UY5VF3DX' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: RTZWY2Y3T1EVLYSCHAIHW4N5W5SGR21LOG1DJFIKWPQBXSZI
# CLIENT_SECRET:A0CY0JWXE3MZV3IQX4AHQH1MICJI3X4D4UFSZC21UY5VF3DX

# %%
#40.7308619 -73.9871558
address = 'Petaling Jaya, Selangor, Malaysia'

geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/geopy/geocoders/osm.py:143: UserWarning: Using Nominatim with the default "geopy/1.17.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   UserWarning
# 3.1055929 101.642697

# %%
search_query = 'restaurant'
radius = 500
print(search_query + ' .... OK!')
# Out:
# restaurant .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=RTZWY2Y3T1EVLYSCHAIHW4N5W5SGR21LOG1DJFIKWPQBXSZI&client_secret=A0CY0JWXE3MZV3IQX4AHQH1MICJI3X4D4UFSZC21UY5VF3DX&ll=3.1055929,101.642697&v=20180604&query=restaurant&radius=500&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5c130357351e3d2f8ce68d8c'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/malaysian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d156941735',
#       'name': 'Malay Restaurant',
#       'pluralName': 'Malay Restaurants',
#       'primary': True,
#       'shortName': 'Malay'}],
#     'hasPerk': False,
#     'id': '50ca02c4245f2d4aa8c2c13b',
#     'location': {'address': 'No 2 Jalan Barat',
#      'cc': 'MY',
#      'city': 'Petaling Jaya',
#      'country': 'Malaysia',
#      'crossStreet': 'Hilton Petaling Jaya',
#      'distance': 431,
#      'formattedAddress': ['No 2 Jalan Barat (Hilton Petaling Jaya)',
#       '46200 Petaling Jaya, NA',
#       'Malaysia'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 3.1020005502741546,
#        'lng': 101.64122772593028}],
#      'lat': 3.1020005502741546,
#      'lng': 101.64122772593028,
# ...

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'name': 'Malay Restaurant', 'icon': {'prefix...    False
# 1  [{'name': 'Japanese Restaurant', 'icon': {'pre...    False
# 2  [{'name': 'Chinese Restaurant', 'icon': {'pref...    False
# 3  [{'name': 'Chinese Restaurant', 'icon': {'pref...    False
# 4  [{'name': 'Japanese Restaurant', 'icon': {'pre...    False
#
#                          id  \
# 0  50ca02c4245f2d4aa8c2c13b
# 1  50ca02c6245f2d4aa8c2c7c1
# 2  5a101704610f04234068f4e3
# 3  4b85e25af964a520ce7731e3
# 4  4d8b5a02401a224b27d5b418
#
#                                     location.address location.cc  \
# 0                                   No 2 Jalan Barat          MY
# 1                                   No 2 Jalan Barat          MY
# 2  Lot 55,, Lorong Utara, Pjs 52, 46700 Petaling ...          MY
# 3  7th Floor, Intan Square, No. 3, Lorong Utara C...          MY
# 4                                Crystal Crown Hotel          MY
#
# ...

# %%
data2=DataFrame(dataframe)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-fea246f3ad0e> in <module>()
# ----> 1 data2=DataFrame(dataframe)
#
# NameError: name 'DataFrame' is not defined

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                                name             categories  \
# 0                             Paya Serai Restaurant       Malay Restaurant
# 1                         Genji Japanese Restaurant    Japanese Restaurant
# 2                            Yue Chinese Restaurant     Chinese Restaurant
# 3                        Imperial Garden Restaurant     Chinese Restaurant
# 4           Sango Japanese Restaurant (三郷日本料理レストラン)    Japanese Restaurant
# 5                       Ume Tei Japanese Restaurant    Japanese Restaurant
# 6                       Oversea Restaurant (海外天大飯店)     Chinese Restaurant
# 7                Restaurant Sederhana Petaling Jaya  Indonesian Restaurant
# 8               Restaurant Sri Saravana Curry House      Indian Restaurant
# 9                     Restaurant BNS Maju Sdn. Bhd.      Indian Restaurant
# 10                                              A&W   Fast Food Restaurant
# ...

# %% [markdown]
# List of Restaurant Within Petaling Jaya Selangor

# %%
dataframe_filtered.name
# Out:
# 0                               Paya Serai Restaurant
# 1                           Genji Japanese Restaurant
# 2                              Yue Chinese Restaurant
# 3                          Imperial Garden Restaurant
# 4             Sango Japanese Restaurant (三郷日本料理レストラン)
# 5                         Ume Tei Japanese Restaurant
# 6                         Oversea Restaurant (海外天大飯店)
# 7                  Restaurant Sederhana Petaling Jaya
# 8                 Restaurant Sri Saravana Curry House
# 9                       Restaurant BNS Maju Sdn. Bhd.
# 10                                                A&W
# 11                 Restaurant Zone Eight White Coffee
# 12                  Restaurant Tou Tou, Seri Petaling
# 13       Restaurant Chef  rasa Sayang Kristal Sdn Bhd
# 14                        Toh Yuen Chinese Restaurant
# 15                               Restoran Syed Bistro
# 16                     Japanese Restaurant, PJ Hilton
# ...

# %% [markdown]
# Category of restaurant within Petaling Jaya

# %%
dataframe_filtered.categories
# Out:
# 0          Malay Restaurant
# 1       Japanese Restaurant
# 2        Chinese Restaurant
# 3        Chinese Restaurant
# 4       Japanese Restaurant
# 5       Japanese Restaurant
# 6        Chinese Restaurant
# 7     Indonesian Restaurant
# 8         Indian Restaurant
# 9         Indian Restaurant
# 10     Fast Food Restaurant
# 11         Asian Restaurant
# 12                     None
# 13                     None
# 14       Chinese Restaurant
# 15         Malay Restaurant
# 16      Japanese Restaurant
# 17       Italian Restaurant
# 18       Chinese Restaurant
# 19          Business Center
# 20                      Pub
# 21    Indonesian Restaurant
# 22       Chinese Restaurant
# 23                     None
# 24        Indian Restaurant
# 25         Asian Restaurant
# 26                Hotel Bar
# 27        Indian Restaurant
# 28        Indian Restaurant
# 29                   Office
# Name: categories, dtype: object

# %% [markdown]
# Location of Restaurant in Map

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Get the respond of sample Restaurant

# %%
venue_id = '50ca02c4245f2d4aa8c2c13b' # ID of Harry's Italian Pizza Bar
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/50ca02c4245f2d4aa8c2c13b?client_id=RTZWY2Y3T1EVLYSCHAIHW4N5W5SGR21LOG1DJFIKWPQBXSZI&client_secret=A0CY0JWXE3MZV3IQX4AHQH1MICJI3X4D4UFSZC21UY5VF3DX&v=20180604'

# %%
venue_id = '50ca02c6245f2d4aa8c2c7c1' # ID of Harry's Italian Pizza Bar
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/50ca02c6245f2d4aa8c2c7c1?client_id=RTZWY2Y3T1EVLYSCHAIHW4N5W5SGR21LOG1DJFIKWPQBXSZI&client_secret=A0CY0JWXE3MZV3IQX4AHQH1MICJI3X4D4UFSZC21UY5VF3DX&v=20180604'

# %% [markdown]
# Get respond from user

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['bestPhoto', 'contact', 'name', 'shortUrl', 'categories', 'createdAt', 'likes', 'inbox', 'specials', 'stats', 'canonicalUrl', 'reasons', 'timeZone', 'ok', 'attributes', 'hereNow', 'photos', 'dislike', 'popular', 'storeId', 'listed', 'tips', 'location', 'rating', 'beenHere', 'id', 'pageUpdates', 'url', 'ratingSignals', 'allowMenuUrlEdit', 'colors', 'page', 'ratingColor', 'verified', 'price'])
# {'allowMenuUrlEdit': True,
#  'attributes': {'groups': [{'count': 1,
#     'items': [{'displayName': 'Price', 'displayValue': '$$', 'priceTier': 2}],
#     'name': 'Price',
#     'summary': '$$',
#     'type': 'price'},
#    {'count': 3,
#     'items': [{'displayName': 'Reservations', 'displayValue': 'Yes'}],
#     'name': 'Reservations',
#     'summary': 'Reservations',
#     'type': 'reservations'},
#    {'count': 5,
#     'items': [{'displayName': 'Credit Cards', 'displayValue': 'Yes'}],
#     'name': 'Credit Cards',
#     'summary': 'Credit Cards',
#     'type': 'payments'},
# ...

# %% [markdown]
# What is respond of customer

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 6.6

# %%
venue_id = '50ca02c4245f2d4aa8c2c13b' # ID of Harry's Italian Pizza Bar
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/50ca02c4245f2d4aa8c2c13b?client_id=RTZWY2Y3T1EVLYSCHAIHW4N5W5SGR21LOG1DJFIKWPQBXSZI&client_secret=A0CY0JWXE3MZV3IQX4AHQH1MICJI3X4D4UFSZC21UY5VF3DX&v=20180604'

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['bestPhoto', 'contact', 'name', 'shortUrl', 'categories', 'createdAt', 'hierarchy', 'likes', 'inbox', 'specials', 'stats', 'canonicalUrl', 'reasons', 'timeZone', 'ok', 'attributes', 'hereNow', 'photos', 'dislike', 'parent', 'popular', 'storeId', 'listed', 'tips', 'location', 'rating', 'beenHere', 'id', 'pageUpdates', 'url', 'ratingSignals', 'allowMenuUrlEdit', 'colors', 'page', 'ratingColor', 'verified', 'price'])
# {'allowMenuUrlEdit': True,
#  'attributes': {'groups': [{'count': 1,
#     'items': [{'displayName': 'Price', 'displayValue': '$$', 'priceTier': 2}],
#     'name': 'Price',
#     'summary': '$$',
#     'type': 'price'},
#    {'count': 3,
#     'items': [{'displayName': 'Reservations', 'displayValue': 'Yes'}],
#     'name': 'Reservations',
#     'summary': 'Reservations',
#     'type': 'reservations'},
#    {'count': 5,
#     'items': [{'displayName': 'Credit Cards', 'displayValue': 'Yes'}],
#     'name': 'Credit Cards',
#     'summary': 'Credit Cards',
# ...

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 5.4

# %%
result['response']['venue']['tips']['count']
# Out:
# 40

# %% [markdown]
# Tips - customer respond

# %%
## Ecco Tips
limit = 15 # set limit to be greater than or equal to the total number of tips
url = 'https://api.foursquare.com/v2/venues/{}/tips?client_id={}&client_secret={}&v={}&limit={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION, limit)

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5c1307fe6a6071723abbae33'},
#  'response': {'tips': {'count': 40,
#    'items': [{'agreeCount': 2,
#      'authorInteractionType': 'disliked',
#      'canonicalUrl': 'https://foursquare.com/item/59184fa13731ee3c7b7f2d48',
#      'createdAt': 1494765473,
#      'disagreeCount': 0,
#      'id': '59184fa13731ee3c7b7f2d48',
#      'lang': 'en',
#      'likes': {'count': 0, 'groups': []},
#      'logView': True,
#      'text': '5-star hotel but serving 3-star buffet dinner. short of utensils, 1 spoon for all. only provide plain water bottle, coffee & tea, no other choices. pricey compared to other same class hotel.',
#      'todo': {'count': 0},
#      'type': 'user',
#      'user': {'firstName': 'Wey Shyan',
#       'gender': 'male',
#       'id': '350146275',
#       'lastName': 'Low',
#       'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
# ...

# %%
tips = results['response']['tips']['items']

tip = results['response']['tips']['items'][0]
tip.keys()
# Out:
# dict_keys(['disagreeCount', 'lang', 'type', 'createdAt', 'agreeCount', 'likes', 'canonicalUrl', 'logView', 'text', 'user', 'id', 'todo', 'authorInteractionType'])

# %%
pd.set_option('display.max_colwidth', -1)

tips_df = json_normalize(tips) # json normalize tips

# columns to keep
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id', 'user.firstName', 'user.lastName', 'user.gender', 'user.id']
tips_filtered = tips_df.loc[:, filtered_columns]

# display tips
tips_filtered
# Out:
#                                                                                                                                                                                              text  \
# 0  5-star hotel but serving 3-star buffet dinner. short of utensils, 1 spoon for all. only provide plain water bottle, coffee & tea, no other choices. pricey compared to other same class hotel.
#
#    agreeCount  disagreeCount                        id user.firstName  \
# 0  2           0              59184fa13731ee3c7b7f2d48  Wey Shyan
#
#   user.lastName user.gender    user.id
# 0  Low           male        350146275

# %%
user_id = '350146275' # user ID with most agree counts and complete profile

url = 'https://api.foursquare.com/v2/users/{}?client_id={}&client_secret={}&v={}'.format(user_id, CLIENT_ID, CLIENT_SECRET, VERSION) # define URL

# send GET request
results = requests.get(url).json()
user_data = results['response']['user']

# display features associated with user
user_data.keys()
# Out:
# dict_keys(['lists', 'lastName', 'canonicalUrl', 'contact', 'type', 'photo', 'bio', 'friends', 'firstName', 'tips', 'id', 'homeCity', 'lenses', 'checkins', 'gender', 'photos', 'mayorships'])

# %%
print('First Name: ' + user_data['firstName'])
print('Last Name: ' + user_data['lastName'])
print('Home City: ' + user_data['homeCity'])
# Out:
# First Name: Wey Shyan
# Last Name: Low
# Home City: Kuala Lumpur, 14

# %%
user_data['tips']
# Out:
# {'count': 1}

# %%
# define tips URL
url = 'https://api.foursquare.com/v2/users/{}/tips?client_id={}&client_secret={}&v={}&limit={}'.format(user_id, CLIENT_ID, CLIENT_SECRET, VERSION, limit)

# send GET request and get user's tips
results = requests.get(url).json()
tips = results['response']['tips']['items']

# format column width
pd.set_option('display.max_colwidth', -1)

tips_df = json_normalize(tips)

# filter columns
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id']
tips_filtered = tips_df.loc[:, filtered_columns]

# display user's tips
tips_filtered
# Out:
#                                                                                                                                                                                              text  \
# 0  5-star hotel but serving 3-star buffet dinner. short of utensils, 1 spoon for all. only provide plain water bottle, coffee & tea, no other choices. pricey compared to other same class hotel.
#
#    agreeCount  disagreeCount                        id
# 0  2           0              59184fa13731ee3c7b7f2d48

# %%
tip_id = '59c7ddbff870fd4a73d1cfe0' # tip id

# define URL
url = 'http://api.foursquare.com/v2/tips/{}?client_id={}&client_secret={}&v={}'.format(tip_id, CLIENT_ID, CLIENT_SECRET, VERSION)

# send GET Request and examine results
result = requests.get(url).json()
print(result['response']['tip']['venue']['name'])
print(result['response']['tip']['venue']['location'])
# Out:
# Melawati Mall
# {'country': 'Malaysia', 'postalCode': '53100', 'cc': 'MY', 'neighborhood': 'Kuala Lumpur', 'address': '355 Jalan Bandar Melawati', 'lat': 3.2105195124343306, 'labeledLatLngs': [{'label': 'display', 'lat': 3.2105195124343306, 'lng': 101.748501640571}], 'lng': 101.748501640571, 'city': 'Kuala Lumpur', 'state': 'Kuala Lumpur', 'crossStreet': 'Taman Melawati', 'formattedAddress': ['355 Jalan Bandar Melawati (Taman Melawati)', '53100 Kuala Lumpur, Kuala Lumpur', 'Malaysia']}
